# %% [markdown]
# SCOUTS POSITIVOS
#
# DS - Desarme (+ 1,0)
#
# G - Gol (+8,0)
#
# A - Assistência (+5,0)
#
# FS - Falta Sofrida ( +0,5)
#
# FF - Finalização para Fora (+0,8)
#
# FD - Finalização Defendida (+1,2)
#
# FT - Finalização na Trave (+3,0)
#
# SCOUTS NEGATIVOS
#
# GC - Gol Contra (-5,0)
#
# CV - Cartão Vermelho (-5,0)
#
# CA - Cartão Amarelo (-2,0)
#
# PP - Pênalti Perdido (-4,0)
#
# FC - Falta Cometida (-0,5)
#
# I - Impedimento (-0,5)
#
# PI - Passe Incompleto (-0,1)

# %%
import pandas as pd

# %%
df_scouts = pd.read_csv("rodada-3.csv")
df_scouts.head(3)
# Out:
#    Unnamed: 0                     atletas.nome   atletas.slug atletas.apelido  \
# 0           1            Danilo Alves da Silva         danilo          Danilo
# 1           2            Jorge de Moura Xavier       jorginho        Jorginho
# 2           3  Thiago Heleno Henrique Ferreira  thiago-heleno   Thiago Heleno
#
#                                         atletas.foto  atletas.atleta_id  \
# 0                                                NaN             107981
# 1  https://s.glbimg.com/es/sde/f/2020/02/27/85109...              77544
# 2  https://s.glbimg.com/es/sde/f/2019/03/30/d941b...              38394
#
#    atletas.rodada_id  atletas.clube_id atletas.posicao_id atletas.status_id  \
# 0                  3               373                zag              Nulo
# 1                  3               373                mei          Provável
# 2                  3               293                zag          Provável
#
#    ...  DD  GS   A  SG  FD  FT   I  CV  GC  PP
# ...

# %%
df_scouts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  716 non-null    int64
#  1   atletas.nome                716 non-null    object
#  2   atletas.slug                716 non-null    object
#  3   atletas.apelido             716 non-null    object
#  4   atletas.foto                709 non-null    object
#  5   atletas.atleta_id           716 non-null    int64
#  6   atletas.rodada_id           716 non-null    int64
#  7   atletas.clube_id            716 non-null    int64
#  8   atletas.posicao_id          716 non-null    object
#  9   atletas.status_id           716 non-null    object
#  10  atletas.pontos_num          716 non-null    float64
#  11  atletas.preco_num           716 non-null    float64
#  12  atletas.variacao_num        716 non-null    float64
# ...

# %%
df_scouts.drop(df_scouts.columns.difference(["atletas.nome","atletas.apelido","atletas.posicao_id",
                               "atletas.clube.id.full.name","DS",
                               "FC","FF","FS","G","PI","CA","A"
                               ,"FD","FT","I","CV","GC","PP"]),axis=1,inplace=True)

# %%
df_scouts.rename({'atletas.nome':'Nome',"atletas.apelido":"Apelido",'atletas.clube.id.full.name':'Clube',
                'atletas.posicao_id':'Posicao','DS':'Desarme','FC':'Falta cometida',"atletas.slug":"Slug",
                'FF':'Finalizacao fora','FS':'Falta sofrida',"G":"Gol",'PI':'Passe Incompleto',
                'CA':'Cartao amarelo','A':'Assistencia','FD':'Finalizacao defendida','FT':'Finalizacao trave',
                'I':'Impedimento','CV':'Cartao vermelho','GC':'Gol contra','PP':'Penalti perdido'},
                axis=1, inplace=True)

# %%
df_scouts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nome                   716 non-null    object
#  1   Apelido                716 non-null    object
#  2   Posicao                716 non-null    object
#  3   Clube                  716 non-null    object
#  4   Desarme                278 non-null    float64
#  5   Falta cometida         273 non-null    float64
#  6   Finalizacao fora       161 non-null    float64
#  7   Falta sofrida          256 non-null    float64
#  8   Gol                    42 non-null     float64
#  9   Passe Incompleto       354 non-null    float64
#  10  Cartao amarelo         95 non-null     float64
#  11  Assistencia            34 non-null     float64
#  12  Finalizacao defendida  118 non-null    float64
#  13  Finalizacao trave      18 non-null     float64
# ...

# %%
df_scouts = df_scouts[df_scouts["Posicao"] != "tec"]

# %%
df_scouts.head()
# Out:
#                               Nome             Apelido Posicao         Clube  \
# 0            Danilo Alves da Silva              Danilo     zag   Atlético-GO
# 1            Jorge de Moura Xavier            Jorginho     mei   Atlético-GO
# 2  Thiago Heleno Henrique Ferreira       Thiago Heleno     zag  Athlético-PR
# 3               Maurício Kozlinski  Maurício Kozlinski     gol   Atlético-GO
# 4            Moacir Costa da Silva              Moacir     mei   Atlético-GO
#
#    Desarme  Falta cometida  Finalizacao fora  Falta sofrida  Gol  \
# 0      NaN             NaN               NaN            NaN  NaN
# 1      7.0             3.0               1.0            3.0  2.0
# 2      3.0             3.0               1.0            2.0  NaN
# 3      NaN             NaN               NaN            NaN  NaN
# 4      1.0             2.0               NaN            NaN  NaN
#
#    Passe Incompleto  Cartao amarelo  Assistencia  Finalizacao defendida  \
# ...

# %%
df_scouts.to_csv('scouts_jogadores.csv',index = False)
